# %% [markdown]
# #### pandas 사용하기

# %%
# panel datas
# 테이블 형식 데이터
# 데이터 베이스 (인덱스, 열)
# csv(인덱스, 열)

# %%
import pandas as pd

# %% [markdown]
# #### pandas 객체 종류

# %%
# numpy 기반해 판다스 제작
# 다차원 배열 제공

# pandas
# 1,2차원 자료 제공
# 1 - Series(시리즈): 인덱스 + 값
# 2 - DataFrame(데이터 프레임): 표와 같은 형태

# %% [markdown]
# #### pandas 객체 다루기

# %% [markdown]
# - 1차원 시리즈 생성1 : 인덱스, 값 입력하여 생성

# %%
num_sr1 = pd.Series([3,4,5] , index = ['son','kim','park'])
num_sr1
# Out:
# son     3
# kim     4
# park    5
# dtype: int64

# %%
num_sr2=pd.Series({'son':3, 'kim':4, 'park':5})
num_sr2
# Out:
# son     3
# kim     4
# park    5
# dtype: int64

# %% [markdown]
# - 1차원 Series 속성 확인

# %%
# 값
num_sr2.values # numpy arr
# 인덱스
num_sr2.index # object : pandas 문자열 등 의미를 포함한 dtype
# 데이터 타입
num_sr2.dtype # int64 : 숫자를 표현할 수 있는 범위값 = 2**64
# Out:
# dtype('int64')

# %%
# 시리즈 이름
num_sr2.name # none
num_sr2.index.name # none

num_sr2.name = 'name_cnt'
num_sr2.index.name='name'
num_sr2
print(num_sr2.name)
print(num_sr2.index.name)
# Series 의 name은 2차원으로 병합될 시 컬럼명으로 인식됨
# Out:
# name_cnt
# name

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
population = pd.Series({'서울':9602000,'부산':334400,'광주':148800,'대구':2419000})
population.name='2020 인구수'
population.index.name='도시'
population
# Out:
# 도시
# 서울    9602000
# 부산     334400
# 광주     148800
# 대구    2419000
# Name: 2020 인구수, dtype: int64

# %%
population= pd.Series([9602000,3344000,1488000,2419000],
                      index=['서울','부산','광주','대구'])
population.name='2020 인구수'
population.index.name='도시'

# %% [markdown]
# - 1차원 시리즈 데이터 갱신(수정),추가

# %%
# 갱신
# 부산>3500000
population['부산']=3500000
# 추가
population['대전']=1500000
# Out:
# 도시
# 서울    9602000
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %%
# 삭제
# population=population.drop('서울')
population.drop('서울',inplace=False) # 삭제해준 결과를 보여줌, 바로 초기화 하진 X
population.drop('서울',inplace=True) # inplace = True 삭제해준 결과를 반영
population
# Out:
# 도시
# 부산    3500000
# 광주    1488000
# 대구    2419000
# 대전    1500000
# Name: 2020 인구수, dtype: int64

# %% [markdown]
# - 2차원 데이터프레임(DataFrame)생성1 - 단일 리스트에 값 입력하여 생성

# %%
num = [1,1,3] # 단일리스트
num_df = pd.DataFrame(num) #일차원을 넣으면
num_df.ndim # 이차원이됨
# Out:
# 2

# %% [markdown]
# - 2차원 데이터프레임 생성 2 - 이중리스트에 값 입력하여 생성

# %%
num2 = [['iot',1],['big',1],['ai',3]]
num2_df=pd.DataFrame(num2,columns=['Class','Join'],index=[1,2,3])
num2_df
# index 값을 설정하려면 사용하는 키워드 : index
# Out:
#   Class  Join
# 1   iot     1
# 2   big     1
# 3    ai     3
