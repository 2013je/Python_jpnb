# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mpg = pd.read_csv('./data/mpg.csv')
# 1.
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
# 2.
display(mpg.head(3))
display(mpg.tail(3))
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 231  midsize
# 232  midsize
# 233  midsize

# %%
# 3
mpg.shape
# Out:
# (234, 11)

# %%
#4.
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 17 to 2
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  18 non-null     object
#  1   model         18 non-null     object
#  2   displ         18 non-null     float64
#  3   year          18 non-null     int64
#  4   cyl           18 non-null     int64
#  5   trans         18 non-null     object
#  6   drv           18 non-null     object
#  7   cty           18 non-null     int64
#  8   hwy           18 non-null     int64
#  9   fl            18 non-null     object
#  10  category      18 non-null     object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.7+ KB

# %%
#5.
mpg.describe()
# 수치형태 데이터를 기준으로 먼저 요약 통계량 확인

mpg.describe(include='all')
# include = 'all' 카테고리 형태 데이터까지 포함해서 요약 통계(+최빈값 freq, 중복없이 unique)
# numpy Nan == np.nan(빈값, 결측치, Null)
# Out:
#        manufacturer       model      displ         year        cyl     trans  \
# count            18          18  18.000000    18.000000  18.000000        18
# unique            1           3        NaN          NaN        NaN         5
# top            audi  a4 quattro        NaN          NaN        NaN  auto(l5)
# freq             18           8        NaN          NaN        NaN         5
# mean            NaN         NaN   2.544444  2003.500000   5.222222       NaN
# std             NaN         NaN   0.673203     4.630462   1.215370       NaN
# min             NaN         NaN   1.800000  1999.000000   4.000000       NaN
# 25%             NaN         NaN   2.000000  1999.000000   4.000000       NaN
# 50%             NaN         NaN   2.800000  2003.500000   6.000000       NaN
# 75%             NaN         NaN   3.025000  2008.000000   6.000000       NaN
# max             NaN         NaN   4.200000  2008.000000   8.000000       NaN
#
#         drv        cty        hwy   fl category
# count    18  18.000000  18.000000   18       18
# unique    2        NaN        NaN    1        2
# top       4        NaN        NaN    p  compact
# freq     11        NaN        NaN   18       15
# mean    NaN  17.611111  26.444444  NaN      NaN
# std     NaN   1.974511   2.175322  NaN      NaN
# min     NaN  15.000000  23.000000  NaN      NaN
# 25%     NaN  16.000000  25.000000  NaN      NaN
# 50%     NaN  17.500000  26.000000  NaN      NaN
# 75%     NaN  18.750000  27.750000  NaN      NaN
# max     NaN  21.000000  31.000000  NaN      NaN

# %%
# 6.
mpg[mpg['manufacturer'] =='audi'].sort_values(ascending=False,by = 'hwy').head(5)
# 쿼리문으로
mpg.sort_values(by='hwy',ascending=False).query('manufacturer=="audi"').head(5)
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact
